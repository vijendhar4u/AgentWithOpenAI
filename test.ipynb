# %%
print("test file 1")
# Out:
# test file

# %%
from dotenv import load_dotenv
import os
    
load_dotenv()

print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
#from langchain_openai import ChatOpenAI

# %%
##chat_llm = ChatOpenAI(model="openai/gpt-4o")

# %%
chat_llm.invoke("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 chat_llm.invoke("What is the capital of France?")
#
# NameError: name 'chat_llm' is not defined
